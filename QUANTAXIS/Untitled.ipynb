# %%
import QUANTAXIS as QA
import datetime

# %%
print QA
# Out:
#   File "<ipython-input-10-92a8094f47f1>", line 1
#     print QA
#            ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
print (QA)
# Out:
# <module 'QUANTAXIS' from '/Users/chenshuai/quantaxis/QUANTAXIS/__init__.py'>

# %%
QA.QA_util_log_info('期货日线')

QA.QAFetch.QATdx.QA_fetch_get_future_day('RB1905','2018-08-01','2018-08-30')
# Out:
# QUANTAXIS>> 期货日线
#               open    high     low   close  position  trade   price  \
# date
# 2018-08-01  3811.0  3848.0  3756.0  3762.0    151304   1025  3818.0
# 2018-08-02  3762.0  3809.0  3749.0  3798.0    153930    696  3773.0
# 2018-08-03  3797.0  3859.0  3795.0  3844.0    152424    894  3831.0
# 2018-08-06  3848.0  3909.0  3785.0  3908.0    158808   1286  3851.0
# 2018-08-07  3910.0  3962.0  3899.0  3935.0    165650    966  3932.0
# 2018-08-08  3935.0  3955.0  3903.0  3918.0    159560    681  3930.0
# 2018-08-09  3918.0  3927.0  3871.0  3918.0    159542    808  3900.0
# 2018-08-10  3918.0  3945.0  3861.0  3863.0    159954    604  3913.0
# 2018-08-13  3877.0  3971.0  3851.0  3966.0    164212    836  3922.0
# 2018-08-14  3968.0  3988.0  3922.0  3936.0    164832    716  3963.0
# 2018-08-15  3946.0  3972.0  3942.0  3964.0    164332    594  3958.0
# 2018-08-16  3959.0  3967.0  3869.0  3936.0    182994   1274  3921.0
# ...
